# %%
import pandas as StkMakTwt_ss

StkMakTwt_Dataset = StkMakTwt_ss.read_csv('/stock_tweets_updated.csv')
StkMakTwt_Dataset.shape
# Out:
# (1286, 2)

# %%
StkMakTwt_Dataset.head(n=10) #head contents
# Out:
#                                                 text  sentiment
# 0  robertbeadles yo enter win monarch tokens us s...          2
# 1  srilanka surcharge fuel removed surcharge rs i...          0
# 2  net issuance increases fund fiscal programs gt...          2
# 3  bentboolean much amazons traffic served fastly...          2
# 4  amd ryzen desktop cpus looking great track lau...          2
# 5  quanttrend reduce portfolio risk gold perfect ...          2
# 6  million sales expected spirit aerosystems hold...          2
# 7  arjunkharpal apple cut prices iphone range chi...          0
# 8  smaalpha cdc us new case data day lag saw anot...          0
# 9  look dependable dividends read gt httpstcoqkvn...          1

# %% [markdown]
# **sentiment**
# positive	denotes - 2
# neutral	denotes - 1
# negative	denotes - 0

# %%
StkMakTwt_Dataset['sentiment'].value_counts()
# Out:
# sentiment
# 2    523
# 1    421
# 0    342
# Name: count, dtype: int64

# %% [markdown]
# Hence positive stock tweets are more.

# %%
# Download required NLTK resources

import nltk as TwtNltk
TwtNltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# Text Preprocessing: Tokenization + Stemming
# =========================

from nltk.stem import PorterStemmer as TwtStemmer
from nltk.tokenize import word_tokenize as TwtToken

# flag to control printing only once
Twt_DebugOnce = True

def Twt_TokenStem_Process(txt_inp):
    global Twt_DebugOnce

    #  Convert to lowercase string
    Twt_txt_lower = str(txt_inp).lower()

    #  Tokenize first (split text into words)
    Twt_tokens = TwtToken(Twt_txt_lower)

    #  Initialize stemmer
    Twt_ps = TwtStemmer()

    #  Apply stemming on each token
    Twt_stemmed_tokens = [Twt_ps.stem(word) for word in Twt_tokens]

    #  Join stemmed tokens back into a single string
    Twt_final_text = " ".join(Twt_stemmed_tokens)

    # Debug print only for the first record
    if Twt_DebugOnce:
        print("* Original Lower Text:", Twt_txt_lower)
        print("* After Tokenization:", Twt_tokens)
        print("* After Stemming:", Twt_stemmed_tokens)
        print("* Final Processed Text:", Twt_final_text)
        Twt_DebugOnce = False  # Disable further prints

    # Return cleaned text
    return Twt_final_text

StkMakTwt_Dataset['text'] = StkMakTwt_Dataset['text'].apply(Twt_TokenStem_Process)
StkMakTwt_Dataset['text']
# Out:
# * Original Lower Text: robertbeadles yo enter win monarch tokens us stock market crashes amp learn pt retweet watch video
# * After Tokenization: ['robertbeadles', 'yo', 'enter', 'win', 'monarch', 'tokens', 'us', 'stock', 'market', 'crashes', 'amp', 'learn', 'pt', 'retweet', 'watch', 'video']
# * After Stemming: ['robertbeadl', 'yo', 'enter', 'win', 'monarch', 'token', 'us', 'stock', 'market', 'crash', 'amp', 'learn', 'pt', 'retweet', 'watch', 'video']
# * Final Processed Text: robertbeadl yo enter win monarch token us stock market crash amp learn pt retweet watch video
# 0       robertbeadl yo enter win monarch token us stoc...
# 1       srilanka surcharg fuel remov surcharg rs impos...
# 2       net issuanc increas fund fiscal program gt yie...
# 3       bentboolean much amazon traffic serv fastli he...
# 4       amd ryzen desktop cpu look great track launch ...
#                               ...
# 1281    stock back recoveri room httpstcohvvlwwodu fai...
# 1282    macrochart breadth expand last week discuss ha...
# 1283    mawsonresourc rompasrajapalot big new camp raj...
# 1284                    aapl qqq top may httpstcoinkwbtxu
# 1285    glg partner lp short posit hilton food group p...
# Name: text, Length: 1286, dtype: object

# %%
#  Feature Extraction (TF-IDF)
# =========================

from sklearn.feature_extraction.text import TfidfVectorizer as TwtVect_TFIDF

Twt_Vectori = TwtVect_TFIDF()
Twt_FeatureX = Twt_Vectori.fit_transform(StkMakTwt_Dataset['text']).toarray()
Twt_FeatureX.shape
# Out:
# (1286, 5782)

# %%
Twt_LabelY = StkMakTwt_Dataset['sentiment']
Twt_LabelY.shape
# Out:
# (1286,)

# %% [markdown]
# ## Borderline-SMOTE

# %%
from imblearn.over_sampling import BorderlineSMOTE as Twt_BSMOTE

print("\n@@ Before BorderlineSMOTE Balancing:")
print(Twt_LabelY.value_counts())

Twt_BSMOTE_StkMak = Twt_BSMOTE(random_state=42, kind='borderline-1')
Twt_FeatureX, Twt_LabelY = Twt_BSMOTE_StkMak.fit_resample(Twt_FeatureX, Twt_LabelY)

print("\n@@ After BorderlineSMOTE Balancing:")
print(Twt_LabelY.value_counts())
print("\nBalanced Training Data Shape:")
print(Twt_FeatureX.shape, Twt_LabelY.shape)
# Out:
# @@ Before BorderlineSMOTE Balancing:
# sentiment
# 2    523
# 1    421
# 0    342
# Name: count, dtype: int64
#
# @@ After BorderlineSMOTE Balancing:
# sentiment
# 2    523
# 0    523
# 1    523
# Name: count, dtype: int64
#
# Balanced Training Data Shape:
# (1569, 5782) (1569,)

# %%
# Train-Test Split
# =========================

from sklearn.model_selection import train_test_split as TwtDataSplit
TwtX_tin_StkMak, TwtX_sin_StkMakt, TwtY_tout_StkMak, TwtY_sout_StkMak = TwtDataSplit(Twt_FeatureX, Twt_LabelY, test_size=0.2, random_state=42, stratify=Twt_LabelY)

# %%
#train , test input & output data
TwtX_tin_StkMak.shape, TwtX_sin_StkMakt.shape, TwtY_tout_StkMak.shape, TwtY_sout_StkMak.shape
# Out:
# ((1255, 5782), (314, 5782), (1255,), (314,))

# %% [markdown]
# #***I. Without hypertuning***

# %% [markdown]
# **Random Forest implementation**

# %%
#  Random Forest (RF) Model
# =========================

from sklearn.ensemble import RandomForestClassifier as TwtRndForest
import time as TwtClock

TwtRF_Start = TwtClock.time()
Twt_RF__StkMak = TwtRndForest()
Twt_RF__StkMak.fit(TwtX_tin_StkMak, TwtY_tout_StkMak)
TwtRF_Time = TwtClock.time() - TwtRF_Start

# Predictions
Twt_RF_Pred_StkMak = Twt_RF__StkMak.predict(TwtX_sin_StkMakt)
Twt_RF_Prob_StkMak = Twt_RF__StkMak.predict_proba(TwtX_sin_StkMakt)

# %%
# Evaluation Function
# =========================

from sklearn.metrics import accuracy_score as Twt_Acc, precision_score as Twt_Prec, recall_score as Twt_Rec, f1_score as Twt_F1, roc_auc_score as Twt_AUC, confusion_matrix as Twt_CM
import numpy as NumStkMakTwt
import matplotlib.pyplot as MkTwtVis
import seaborn as TwtSeaVis

def Twt_ModelEval(Y_true_StkMak, Y_pred_StkMak, Y_prob_StkMak, Twt_ModelName, Twt_ExeTime):
    TwtAcc = Twt_Acc(Y_true_StkMak, Y_pred_StkMak)
    TwtPrec = Twt_Prec(Y_true_StkMak, Y_pred_StkMak, average='weighted')
    TwtRec = Twt_Rec(Y_true_StkMak, Y_pred_StkMak, average='weighted')
    TwtF1 = Twt_F1(Y_true_StkMak, Y_pred_StkMak, average='weighted')

    try:
        TwtAUC = Twt_AUC(Y_true_StkMak, Y_prob_StkMak, multi_class='ovr')
    except ValueError:
        TwtAUC = NumStkMakTwt.nan


    print(f"\n{Twt_ModelName} Performance Metrics:")
    print(f"Accuracy  : {TwtAcc:.3f}")
    print(f"Precision : {TwtPrec:.3f}")
    print(f"Recall    : {TwtRec:.3f}")
    print(f"F1-score  : {TwtF1:.3f}")
    print(f"AUC       : {TwtAUC:.3f}")
    print(f"Execution Time: {Twt_ExeTime:.2f} sec")

    Twt_ConfMat = Twt_CM(Y_true_StkMak, Y_pred_StkMak)
    Twt_Lbls = ['Negative (0)', 'Neutral (1)', 'Positive (2)']

    TwtSeaVis.heatmap(Twt_ConfMat, annot=True, fmt='d', cmap='Blues',
                      xticklabels=Twt_Lbls, yticklabels=Twt_Lbls)
    MkTwtVis.title(f'{Twt_ModelName} - Confusion Matrix')
    MkTwtVis.xlabel('Predicted Sentiment')
    MkTwtVis.ylabel('Actual Sentiment')
    MkTwtVis.show()

    return [Twt_ModelName, TwtAcc, TwtPrec, TwtRec, TwtF1, TwtAUC, Twt_ExeTime]

# %%
# Evaluate RF models
TwtRF_Res = Twt_ModelEval(TwtY_sout_StkMak, Twt_RF_Pred_StkMak, Twt_RF_Prob_StkMak, "Random Forest (RF)", TwtRF_Time)
# Out:
# Random Forest (RF) Performance Metrics:
# Accuracy  : 0.669
# Precision : 0.682
# Recall    : 0.669
# F1-score  : 0.669
# AUC       : 0.846
# Execution Time: 3.42 sec

# %% [markdown]
# **Weighted Random Forest implementation**

# %%
#  Weighted Random Forest (WRF) Model
# =========================
from sklearn.utils.class_weight import compute_class_weight as Twt_WeightCalc
import time as TwtClock
import numpy as NumStkMakTwt

Twt_ClassWeights_StkMak = Twt_WeightCalc('balanced', classes=NumStkMakTwt.unique(TwtY_tout_StkMak), y=TwtY_tout_StkMak)
Twt_ClassWeight_Dict_StkMak = {i: Twt_ClassWeights_StkMak[i] for i in range(len(Twt_ClassWeights_StkMak))}
print("Computed Class Weights:", Twt_ClassWeight_Dict_StkMak)

TwtWRF_Start = TwtClock.time()
Twt_WRF_Model = TwtRndForest(class_weight=Twt_ClassWeight_Dict_StkMak)
Twt_WRF_Model.fit(TwtX_tin_StkMak, TwtY_tout_StkMak)
TwtWRF_Time = TwtClock.time() - TwtWRF_Start

# Predictions
Twt_WRF_Pred_StkMak = Twt_WRF_Model.predict(TwtX_sin_StkMakt)
Twt_WRF_Prob_StkMak = Twt_WRF_Model.predict_proba(TwtX_sin_StkMakt)
# Out:
# Computed Class Weights: {0: np.float64(0.9984089101034208), 1: np.float64(1.0007974481658692), 2: np.float64(1.0007974481658692)}

# %%
# Evaluate WRF models

TwtWRF_Res = Twt_ModelEval(TwtY_sout_StkMak, Twt_WRF_Pred_StkMak, Twt_WRF_Prob_StkMak, "Weighted Random Forest (WRF)", TwtWRF_Time)
# Out:
# Weighted Random Forest (WRF) Performance Metrics:
# Accuracy  : 0.675
# Precision : 0.691
# Recall    : 0.675
# F1-score  : 0.677
# AUC       : 0.853
# Execution Time: 3.56 sec

# %%
#  Model Comparison
# =========================

Twt_ModelCompare = StkMakTwt_ss.DataFrame([TwtRF_Res, TwtWRF_Res],
                                   columns=["Model", "Accuracy", "Precision", "Recall", "F1-score", "AUC", "Execution Time (sec)"])

print("\n=== Model Comparison Summary ===")
print(Twt_ModelCompare)
# Out:
# === Model Comparison Summary ===
#                           Model  Accuracy  Precision    Recall  F1-score  \
# 0            Random Forest (RF)  0.668790   0.682390  0.668790  0.669248
# 1  Weighted Random Forest (WRF)  0.675159   0.691338  0.675159  0.676720
#
#         AUC  Execution Time (sec)
# 0  0.845904              3.419961
# 1  0.852680              3.560732

# %% [markdown]
# #***II. With hypertuning***

# %%
#  Finding best hyperparameters with Grid Search
# =========================

from sklearn.model_selection import GridSearchCV as Twt_GridSrch

# Define parameter grid for tuning
Twt_ParamGrid = {
    'n_estimators': [100, 50, 150],
    'max_depth': [None, 10, 20, 30, 40],
    'min_samples_split': [2, 5, 10, 20],
    'min_samples_leaf': [1, 2, 4, 5],
    'bootstrap': [True, False]
}

Twt_RF_Base = TwtRndForest()

# Apply Grid Search with 2-fold CV
Twt_GridSrch_RF = Twt_GridSrch(estimator=Twt_RF_Base,
                                param_grid=Twt_ParamGrid,
                                cv=2,
                                n_jobs=-1,
                                verbose=2,
                                scoring='accuracy')

Twt_GridSrch_RF.fit(TwtX_tin_StkMak, TwtY_tout_StkMak)

# Get best parameters
print("\n @@ Best Hyperparameters found by Grid Search:")
print(Twt_GridSrch_RF.best_params_)
# Out:
# Fitting 2 folds for each of 480 candidates, totalling 960 fits
#
#  @@ Best Hyperparameters found by Grid Search:
# {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}

# %% [markdown]
# **Random Forest implementation**

# %%
#  Random Forest (RF) Model with Grid Search
# =========================

TwtRF_Start = TwtClock.time()
Twt_RF__StkMak = TwtRndForest(**Twt_GridSrch_RF.best_params_)
Twt_RF__StkMak.fit(TwtX_tin_StkMak, TwtY_tout_StkMak)
TwtRF_Time = TwtClock.time() - TwtRF_Start

# Predictions
Twt_RF_Pred_StkMak = Twt_RF__StkMak.predict(TwtX_sin_StkMakt)
Twt_RF_Prob_StkMak = Twt_RF__StkMak.predict_proba(TwtX_sin_StkMakt)

# Evaluate RF models
TwtRF_Res = Twt_ModelEval(TwtY_sout_StkMak, Twt_RF_Pred_StkMak, Twt_RF_Prob_StkMak, "Random Forest (RF)", TwtRF_Time)
# Out:
# Random Forest (RF) Performance Metrics:
# Accuracy  : 0.678
# Precision : 0.691
# Recall    : 0.678
# F1-score  : 0.681
# AUC       : 0.843
# Execution Time: 5.99 sec

# %% [markdown]
# **Weighted Random Forest implementation**

# %%
#  Weighted Random Forest (WRF) Model with Grid Search
# =========================

Twt_ClassWeights_StkMak = Twt_WeightCalc('balanced', classes=NumStkMakTwt.unique(TwtY_tout_StkMak), y=TwtY_tout_StkMak)
Twt_ClassWeight_Dict_StkMak = {i: Twt_ClassWeights_StkMak[i] for i in range(len(Twt_ClassWeights_StkMak))}
print("Computed Class Weights:", Twt_ClassWeight_Dict_StkMak)

TwtWRF_Start = TwtClock.time()
Twt_WRF_Model = TwtRndForest(**Twt_GridSrch_RF.best_params_, class_weight=Twt_ClassWeight_Dict_StkMak)
Twt_WRF_Model.fit(TwtX_tin_StkMak, TwtY_tout_StkMak)
TwtWRF_Time = TwtClock.time() - TwtWRF_Start

# Predictions
Twt_WRF_Pred_StkMak = Twt_WRF_Model.predict(TwtX_sin_StkMakt)
Twt_WRF_Prob_StkMak = Twt_WRF_Model.predict_proba(TwtX_sin_StkMakt)

# Evaluate WRF models
TwtWRF_Res = Twt_ModelEval(TwtY_sout_StkMak, Twt_WRF_Pred_StkMak, Twt_WRF_Prob_StkMak, "Weighted Random Forest (WRF)", TwtWRF_Time)
# Out:
# Computed Class Weights: {0: np.float64(0.9984089101034208), 1: np.float64(1.0007974481658692), 2: np.float64(1.0007974481658692)}
#
# Weighted Random Forest (WRF) Performance Metrics:
# Accuracy  : 0.669
# Precision : 0.679
# Recall    : 0.669
# F1-score  : 0.670
# AUC       : 0.849
# Execution Time: 6.41 sec

# %%
#  Model Comparison
# =========================

Twt_ModelCompare = StkMakTwt_ss.DataFrame([TwtRF_Res, TwtWRF_Res],
                                   columns=["Model", "Accuracy", "Precision", "Recall", "F1-score", "AUC", "Execution Time (sec)"])

print("\n=== Model Comparison Summary ===")
print(Twt_ModelCompare)
# Out:
# === Model Comparison Summary ===
#                           Model  Accuracy  Precision    Recall  F1-score  \
# 0            Random Forest (RF)  0.678344   0.690627  0.678344  0.680763
# 1  Weighted Random Forest (WRF)  0.668790   0.679137  0.668790  0.670480
#
#         AUC  Execution Time (sec)
# 0  0.842978               5.98683
# 1  0.848925               6.41239

# %% [markdown]
# **Artificial Neural Network (ANN)**

# %%
# *** Artificial Neural Network (ANN)***
# =====================================================

import tensorflow as TwtTF
from tensorflow.keras.models import Sequential as TwtSeqModel
from tensorflow.keras.layers import Dense as TwtDense, Dropout as TwtDrop
from tensorflow.keras.callbacks import EarlyStopping as TwtEarlyStop, ReduceLROnPlateau as TwtLRReduce
import time as TwtClock

# Build hypertuned ANN
Twt_ANN_Model = TwtSeqModel()
Twt_ANN_Model.add(TwtDense(256, activation='relu', input_shape=(TwtX_tin_StkMak.shape[1],),
                           kernel_regularizer=TwtTF.keras.regularizers.l2(0.001)))
Twt_ANN_Model.add(TwtDrop(0.4))
Twt_ANN_Model.add(TwtDense(128, activation='relu', kernel_regularizer=TwtTF.keras.regularizers.l2(0.001)))
Twt_ANN_Model.add(TwtDrop(0.3))
Twt_ANN_Model.add(TwtDense(64, activation='relu'))
Twt_ANN_Model.add(TwtDrop(0.2))
Twt_ANN_Model.add(TwtDense(3, activation='softmax'))

# Compile with tuned optimizer
Twt_ANN_Model.compile(loss='sparse_categorical_crossentropy',
                      optimizer=TwtTF.keras.optimizers.Adam(learning_rate=1e-3),
                      metrics=['accuracy'])

# Callbacks for hypertuning
Twt_callbacks = [
    TwtEarlyStop(monitor='val_loss', patience=100, restore_best_weights=True),
    TwtLRReduce(monitor='val_loss', factor=0.5, patience=100, min_lr=1e-5)
]

# Train hypertuned ANN
TwtANN_Start = TwtClock.time()
Twt_ANN_History = Twt_ANN_Model.fit(TwtX_tin_StkMak, TwtY_tout_StkMak,
                                    validation_data=(TwtX_sin_StkMakt, TwtY_sout_StkMak),
                                    epochs=100,
                                    batch_size=32,
                                    callbacks=Twt_callbacks,
                                    verbose=2)
TwtANN_Time = TwtClock.time() - TwtANN_Start

# Predictions
Twt_ANN_Pred_Prob = Twt_ANN_Model.predict(TwtX_sin_StkMakt)
Twt_ANN_Pred_Label = TwtTF.argmax(Twt_ANN_Pred_Prob, axis=1)

# Evaluate ANN
TwtANN_Res = Twt_ModelEval(TwtY_sout_StkMak, Twt_ANN_Pred_Label, Twt_ANN_Pred_Prob,
                           "ANN", TwtANN_Time)

# Add to comparison
Twt_ModelCompare = StkMakTwt_ss.DataFrame([TwtANN_Res],
                                   columns=["Model", "Accuracy", "Precision", "Recall", "F1-score", "AUC", "Execution Time (sec)"])
print("\n=== ANN Model Comparison Summary ===")
print(Twt_ModelCompare)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 40/40 - 4s - 99ms/step - accuracy: 0.3857 - loss: 1.3629 - val_accuracy: 0.4873 - val_loss: 1.1989 - learning_rate: 1.0000e-03
# Epoch 2/100
# 40/40 - 1s - 26ms/step - accuracy: 0.5817 - loss: 1.0347 - val_accuracy: 0.5796 - val_loss: 0.9311 - learning_rate: 1.0000e-03
# Epoch 3/100
# 40/40 - 1s - 25ms/step - accuracy: 0.8390 - loss: 0.5823 - val_accuracy: 0.6975 - val_loss: 0.8788 - learning_rate: 1.0000e-03
# Epoch 4/100
# 40/40 - 1s - 32ms/step - accuracy: 0.9697 - loss: 0.2917 - val_accuracy: 0.6783 - val_loss: 0.9370 - learning_rate: 1.0000e-03
# Epoch 5/100
# 40/40 - 1s - 26ms/step - accuracy: 0.9920 - loss: 0.2066 - val_accuracy: 0.7197 - val_loss: 0.9484 - learning_rate: 1.0000e-03
# Epoch 6/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9912 - loss: 0.1813 - val_accuracy: 0.7102 - val_loss: 1.0649 - learning_rate: 1.0000e-03
# Epoch 7/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9936 - loss: 0.1711 - val_accuracy: 0.7197 - val_loss: 0.9824 - learning_rate: 1.0000e-03
# Epoch 8/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9952 - loss: 0.1529 - val_accuracy: 0.7229 - val_loss: 0.9833 - learning_rate: 1.0000e-03
# Epoch 9/100
# 40/40 - 1s - 26ms/step - accuracy: 0.9952 - loss: 0.1433 - val_accuracy: 0.7102 - val_loss: 1.0092 - learning_rate: 1.0000e-03
# Epoch 10/100
# 40/40 - 1s - 37ms/step - accuracy: 0.9952 - loss: 0.1384 - val_accuracy: 0.7261 - val_loss: 1.0030 - learning_rate: 1.0000e-03
# Epoch 11/100
# 40/40 - 2s - 56ms/step - accuracy: 0.9944 - loss: 0.1439 - val_accuracy: 0.6879 - val_loss: 1.0379 - learning_rate: 1.0000e-03
# Epoch 12/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9976 - loss: 0.1312 - val_accuracy: 0.7038 - val_loss: 1.0547 - learning_rate: 1.0000e-03
# Epoch 13/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9968 - loss: 0.1213 - val_accuracy: 0.6752 - val_loss: 1.1059 - learning_rate: 1.0000e-03
# Epoch 14/100
# 40/40 - 1s - 33ms/step - accuracy: 0.9960 - loss: 0.1329 - val_accuracy: 0.7006 - val_loss: 1.1491 - learning_rate: 1.0000e-03
# Epoch 15/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9936 - loss: 0.1339 - val_accuracy: 0.6561 - val_loss: 1.4046 - learning_rate: 1.0000e-03
# Epoch 16/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9928 - loss: 0.1482 - val_accuracy: 0.6783 - val_loss: 1.2676 - learning_rate: 1.0000e-03
# Epoch 17/100
# 40/40 - 1s - 26ms/step - accuracy: 0.9944 - loss: 0.1416 - val_accuracy: 0.6752 - val_loss: 1.2898 - learning_rate: 1.0000e-03
# Epoch 18/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9968 - loss: 0.1350 - val_accuracy: 0.6943 - val_loss: 1.2372 - learning_rate: 1.0000e-03
# Epoch 19/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9928 - loss: 0.1388 - val_accuracy: 0.6911 - val_loss: 1.2233 - learning_rate: 1.0000e-03
# Epoch 20/100
# 40/40 - 1s - 26ms/step - accuracy: 0.9904 - loss: 0.1541 - val_accuracy: 0.6720 - val_loss: 1.2529 - learning_rate: 1.0000e-03
# Epoch 21/100
# 40/40 - 2s - 41ms/step - accuracy: 0.9912 - loss: 0.1551 - val_accuracy: 0.7038 - val_loss: 1.2393 - learning_rate: 1.0000e-03
# Epoch 22/100
# 40/40 - 1s - 36ms/step - accuracy: 0.9976 - loss: 0.1371 - val_accuracy: 0.6975 - val_loss: 1.3093 - learning_rate: 1.0000e-03
# Epoch 23/100
# 40/40 - 2s - 53ms/step - accuracy: 0.9944 - loss: 0.1386 - val_accuracy: 0.6911 - val_loss: 1.2659 - learning_rate: 1.0000e-03
# Epoch 24/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9944 - loss: 0.1374 - val_accuracy: 0.6911 - val_loss: 1.2253 - learning_rate: 1.0000e-03
# Epoch 25/100
# 40/40 - 1s - 26ms/step - accuracy: 0.9928 - loss: 0.1314 - val_accuracy: 0.6752 - val_loss: 1.3363 - learning_rate: 1.0000e-03
# Epoch 26/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9952 - loss: 0.1337 - val_accuracy: 0.7102 - val_loss: 1.2519 - learning_rate: 1.0000e-03
# Epoch 27/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9944 - loss: 0.1316 - val_accuracy: 0.6847 - val_loss: 1.2771 - learning_rate: 1.0000e-03
# Epoch 28/100
# 40/40 - 1s - 32ms/step - accuracy: 0.9952 - loss: 0.1242 - val_accuracy: 0.6847 - val_loss: 1.2779 - learning_rate: 1.0000e-03
# Epoch 29/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9960 - loss: 0.1259 - val_accuracy: 0.7070 - val_loss: 1.2990 - learning_rate: 1.0000e-03
# Epoch 30/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9960 - loss: 0.1245 - val_accuracy: 0.7038 - val_loss: 1.3097 - learning_rate: 1.0000e-03
# Epoch 31/100
# 40/40 - 1s - 28ms/step - accuracy: 0.9936 - loss: 0.1312 - val_accuracy: 0.7261 - val_loss: 1.2035 - learning_rate: 1.0000e-03
# Epoch 32/100
# 40/40 - 1s - 36ms/step - accuracy: 0.9920 - loss: 0.1251 - val_accuracy: 0.6847 - val_loss: 1.2838 - learning_rate: 1.0000e-03
# Epoch 33/100
# 40/40 - 2s - 53ms/step - accuracy: 0.9960 - loss: 0.1226 - val_accuracy: 0.6911 - val_loss: 1.3381 - learning_rate: 1.0000e-03
# Epoch 34/100
# 40/40 - 1s - 26ms/step - accuracy: 0.9968 - loss: 0.1201 - val_accuracy: 0.6911 - val_loss: 1.3611 - learning_rate: 1.0000e-03
# Epoch 35/100
# 40/40 - 1s - 30ms/step - accuracy: 0.9960 - loss: 0.1133 - val_accuracy: 0.6815 - val_loss: 1.3864 - learning_rate: 1.0000e-03
# Epoch 36/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9976 - loss: 0.1062 - val_accuracy: 0.6911 - val_loss: 1.3749 - learning_rate: 1.0000e-03
# Epoch 37/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9928 - loss: 0.1164 - val_accuracy: 0.6624 - val_loss: 1.5152 - learning_rate: 1.0000e-03
# Epoch 38/100
# 40/40 - 1s - 31ms/step - accuracy: 0.9880 - loss: 0.1383 - val_accuracy: 0.6752 - val_loss: 1.3642 - learning_rate: 1.0000e-03
# Epoch 39/100
# 40/40 - 1s - 32ms/step - accuracy: 0.9841 - loss: 0.1626 - val_accuracy: 0.7070 - val_loss: 1.3188 - learning_rate: 1.0000e-03
# Epoch 40/100
# 40/40 - 1s - 31ms/step - accuracy: 0.9904 - loss: 0.1511 - val_accuracy: 0.7038 - val_loss: 1.3725 - learning_rate: 1.0000e-03
# Epoch 41/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9960 - loss: 0.1431 - val_accuracy: 0.6783 - val_loss: 1.4977 - learning_rate: 1.0000e-03
# Epoch 42/100
# 40/40 - 2s - 44ms/step - accuracy: 0.9920 - loss: 0.1608 - val_accuracy: 0.6975 - val_loss: 1.4608 - learning_rate: 1.0000e-03
# Epoch 43/100
# 40/40 - 2s - 53ms/step - accuracy: 0.9968 - loss: 0.1362 - val_accuracy: 0.6847 - val_loss: 1.4075 - learning_rate: 1.0000e-03
# Epoch 44/100
# 40/40 - 1s - 28ms/step - accuracy: 0.9976 - loss: 0.1220 - val_accuracy: 0.6783 - val_loss: 1.3924 - learning_rate: 1.0000e-03
# Epoch 45/100
# 40/40 - 2s - 42ms/step - accuracy: 0.9984 - loss: 0.1216 - val_accuracy: 0.6879 - val_loss: 1.4048 - learning_rate: 1.0000e-03
# Epoch 46/100
# 40/40 - 2s - 39ms/step - accuracy: 0.9944 - loss: 0.1189 - val_accuracy: 0.6911 - val_loss: 1.3908 - learning_rate: 1.0000e-03
# Epoch 47/100
# 40/40 - 3s - 65ms/step - accuracy: 0.9960 - loss: 0.1199 - val_accuracy: 0.6815 - val_loss: 1.4100 - learning_rate: 1.0000e-03
# Epoch 48/100
# 40/40 - 3s - 73ms/step - accuracy: 0.9960 - loss: 0.1134 - val_accuracy: 0.6975 - val_loss: 1.3326 - learning_rate: 1.0000e-03
# Epoch 49/100
# 40/40 - 2s - 43ms/step - accuracy: 0.9952 - loss: 0.1100 - val_accuracy: 0.7166 - val_loss: 1.2782 - learning_rate: 1.0000e-03
# Epoch 50/100
# 40/40 - 2s - 39ms/step - accuracy: 0.9968 - loss: 0.1060 - val_accuracy: 0.7166 - val_loss: 1.2999 - learning_rate: 1.0000e-03
# Epoch 51/100
# 40/40 - 2s - 55ms/step - accuracy: 0.9960 - loss: 0.1029 - val_accuracy: 0.7006 - val_loss: 1.3324 - learning_rate: 1.0000e-03
# Epoch 52/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9944 - loss: 0.1076 - val_accuracy: 0.7229 - val_loss: 1.3194 - learning_rate: 1.0000e-03
# Epoch 53/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9968 - loss: 0.1044 - val_accuracy: 0.7070 - val_loss: 1.3665 - learning_rate: 1.0000e-03
# Epoch 54/100
# 40/40 - 1s - 32ms/step - accuracy: 0.9936 - loss: 0.1132 - val_accuracy: 0.6847 - val_loss: 1.3351 - learning_rate: 1.0000e-03
# Epoch 55/100
# 40/40 - 1s - 27ms/step - accuracy: 0.9896 - loss: 0.1227 - val_accuracy: 0.6815 - val_loss: 1.3696 - learning_rate: 1.0000e-03
# Epoch 56/100
# 40/40 - 1s - 30ms/step - accuracy: 0.9952 - loss: 0.1166 - val_accuracy: 0.7006 - val_loss: 1.3693 - learning_rate: 1.0000e-03
# Epoch 57/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9936 - loss: 0.1107 - val_accuracy: 0.6847 - val_loss: 1.4631 - learning_rate: 1.0000e-03
# Epoch 58/100
# 40/40 - 1s - 26ms/step - accuracy: 0.9896 - loss: 0.1245 - val_accuracy: 0.6879 - val_loss: 1.5044 - learning_rate: 1.0000e-03
# Epoch 59/100
# 40/40 - 2s - 38ms/step - accuracy: 0.9880 - loss: 0.1469 - val_accuracy: 0.7070 - val_loss: 1.4919 - learning_rate: 1.0000e-03
# Epoch 60/100
# 40/40 - 1s - 37ms/step - accuracy: 0.9928 - loss: 0.1361 - val_accuracy: 0.6879 - val_loss: 1.4493 - learning_rate: 1.0000e-03
# Epoch 61/100
# 40/40 - 1s - 32ms/step - accuracy: 0.9952 - loss: 0.1200 - val_accuracy: 0.6911 - val_loss: 1.4973 - learning_rate: 1.0000e-03
# Epoch 62/100
# 40/40 - 1s - 26ms/step - accuracy: 0.9912 - loss: 0.1324 - val_accuracy: 0.6783 - val_loss: 1.4087 - learning_rate: 1.0000e-03
# Epoch 63/100
# 40/40 - 1s - 31ms/step - accuracy: 0.9944 - loss: 0.1238 - val_accuracy: 0.6847 - val_loss: 1.4670 - learning_rate: 1.0000e-03
# Epoch 64/100
# 40/40 - 1s - 32ms/step - accuracy: 0.9976 - loss: 0.1130 - val_accuracy: 0.6911 - val_loss: 1.4810 - learning_rate: 1.0000e-03
# Epoch 65/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9952 - loss: 0.1117 - val_accuracy: 0.7006 - val_loss: 1.4724 - learning_rate: 1.0000e-03
# Epoch 66/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9944 - loss: 0.1165 - val_accuracy: 0.7134 - val_loss: 1.4981 - learning_rate: 1.0000e-03
# Epoch 67/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9896 - loss: 0.1288 - val_accuracy: 0.7038 - val_loss: 1.4902 - learning_rate: 1.0000e-03
# Epoch 68/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9904 - loss: 0.1410 - val_accuracy: 0.6975 - val_loss: 1.6441 - learning_rate: 1.0000e-03
# Epoch 69/100
# 40/40 - 1s - 32ms/step - accuracy: 0.9928 - loss: 0.1397 - val_accuracy: 0.6720 - val_loss: 1.5025 - learning_rate: 1.0000e-03
# Epoch 70/100
# 40/40 - 1s - 31ms/step - accuracy: 0.9920 - loss: 0.1580 - val_accuracy: 0.6688 - val_loss: 1.5971 - learning_rate: 1.0000e-03
# Epoch 71/100
# 40/40 - 1s - 37ms/step - accuracy: 0.9928 - loss: 0.1425 - val_accuracy: 0.6879 - val_loss: 1.5799 - learning_rate: 1.0000e-03
# Epoch 72/100
# 40/40 - 2s - 38ms/step - accuracy: 0.9968 - loss: 0.1301 - val_accuracy: 0.7102 - val_loss: 1.4153 - learning_rate: 1.0000e-03
# Epoch 73/100
# 40/40 - 1s - 26ms/step - accuracy: 0.9944 - loss: 0.1252 - val_accuracy: 0.6943 - val_loss: 1.4496 - learning_rate: 1.0000e-03
# Epoch 74/100
# 40/40 - 1s - 32ms/step - accuracy: 0.9960 - loss: 0.1202 - val_accuracy: 0.7070 - val_loss: 1.3704 - learning_rate: 1.0000e-03
# Epoch 75/100
# 40/40 - 1s - 31ms/step - accuracy: 0.9944 - loss: 0.1213 - val_accuracy: 0.6911 - val_loss: 1.5223 - learning_rate: 1.0000e-03
# Epoch 76/100
# 40/40 - 1s - 31ms/step - accuracy: 0.9984 - loss: 0.1138 - val_accuracy: 0.7102 - val_loss: 1.4954 - learning_rate: 1.0000e-03
# Epoch 77/100
# 40/40 - 1s - 26ms/step - accuracy: 0.9960 - loss: 0.1104 - val_accuracy: 0.7038 - val_loss: 1.5015 - learning_rate: 1.0000e-03
# Epoch 78/100
# 40/40 - 1s - 26ms/step - accuracy: 0.9968 - loss: 0.1117 - val_accuracy: 0.6879 - val_loss: 1.5060 - learning_rate: 1.0000e-03
# Epoch 79/100
# 40/40 - 1s - 26ms/step - accuracy: 0.9976 - loss: 0.1053 - val_accuracy: 0.6783 - val_loss: 1.5580 - learning_rate: 1.0000e-03
# Epoch 80/100
# 40/40 - 1s - 31ms/step - accuracy: 0.9952 - loss: 0.1066 - val_accuracy: 0.6879 - val_loss: 1.4660 - learning_rate: 1.0000e-03
# Epoch 81/100
# 40/40 - 1s - 24ms/step - accuracy: 0.9968 - loss: 0.1047 - val_accuracy: 0.6815 - val_loss: 1.5168 - learning_rate: 1.0000e-03
# Epoch 82/100
# 40/40 - 2s - 43ms/step - accuracy: 0.9968 - loss: 0.1059 - val_accuracy: 0.6943 - val_loss: 1.4829 - learning_rate: 1.0000e-03
# Epoch 83/100
# 40/40 - 1s - 37ms/step - accuracy: 0.9952 - loss: 0.1059 - val_accuracy: 0.6783 - val_loss: 1.4645 - learning_rate: 1.0000e-03
# Epoch 84/100
# 40/40 - 1s - 28ms/step - accuracy: 0.9960 - loss: 0.1079 - val_accuracy: 0.6879 - val_loss: 1.3806 - learning_rate: 1.0000e-03
# Epoch 85/100
# 40/40 - 1s - 28ms/step - accuracy: 0.9960 - loss: 0.1049 - val_accuracy: 0.6975 - val_loss: 1.3722 - learning_rate: 1.0000e-03
# Epoch 86/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9952 - loss: 0.1098 - val_accuracy: 0.7134 - val_loss: 1.3707 - learning_rate: 1.0000e-03
# Epoch 87/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9976 - loss: 0.1003 - val_accuracy: 0.6879 - val_loss: 1.3903 - learning_rate: 1.0000e-03
# Epoch 88/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9952 - loss: 0.0973 - val_accuracy: 0.6943 - val_loss: 1.4244 - learning_rate: 1.0000e-03
# Epoch 89/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9920 - loss: 0.1063 - val_accuracy: 0.6975 - val_loss: 1.4372 - learning_rate: 1.0000e-03
# Epoch 90/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9920 - loss: 0.1141 - val_accuracy: 0.6911 - val_loss: 1.4291 - learning_rate: 1.0000e-03
# Epoch 91/100
# 40/40 - 1s - 31ms/step - accuracy: 0.9976 - loss: 0.0997 - val_accuracy: 0.6752 - val_loss: 1.4907 - learning_rate: 1.0000e-03
# Epoch 92/100
# 40/40 - 1s - 25ms/step - accuracy: 0.9928 - loss: 0.1038 - val_accuracy: 0.6879 - val_loss: 1.5217 - learning_rate: 1.0000e-03
# Epoch 93/100
# 40/40 - 1s - 37ms/step - accuracy: 0.9888 - loss: 0.1198 - val_accuracy: 0.6815 - val_loss: 1.5321 - learning_rate: 1.0000e-03
# Epoch 94/100
# 40/40 - 2s - 38ms/step - accuracy: 0.9920 - loss: 0.1264 - val_accuracy: 0.6815 - val_loss: 1.4381 - learning_rate: 1.0000e-03
# Epoch 95/100
# 40/40 - 2s - 39ms/step - accuracy: 0.9920 - loss: 0.1170 - val_accuracy: 0.6847 - val_loss: 1.5500 - learning_rate: 1.0000e-03
# Epoch 96/100
# 40/40 - 1s - 28ms/step - accuracy: 0.9912 - loss: 0.1203 - val_accuracy: 0.7070 - val_loss: 1.4018 - learning_rate: 1.0000e-03
# Epoch 97/100
# 40/40 - 1s - 30ms/step - accuracy: 0.9888 - loss: 0.1316 - val_accuracy: 0.6752 - val_loss: 1.4930 - learning_rate: 1.0000e-03
# Epoch 98/100
# 40/40 - 1s - 31ms/step - accuracy: 0.9960 - loss: 0.1161 - val_accuracy: 0.6911 - val_loss: 1.5126 - learning_rate: 1.0000e-03
# Epoch 99/100
# 40/40 - 1s - 31ms/step - accuracy: 0.9936 - loss: 0.1192 - val_accuracy: 0.6752 - val_loss: 1.5831 - learning_rate: 1.0000e-03
# Epoch 100/100
# 40/40 - 1s - 24ms/step - accuracy: 0.9936 - loss: 0.1191 - val_accuracy: 0.6688 - val_loss: 1.5246 - learning_rate: 1.0000e-03
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# ANN Performance Metrics:
# Accuracy  : 0.697
# Precision : 0.705
# Recall    : 0.697
# F1-score  : 0.695
# AUC       : 0.868
# Execution Time: 129.89 sec
# === ANN Model Comparison Summary ===
#   Model  Accuracy  Precision    Recall  F1-score       AUC  \
# 0   ANN  0.697452   0.704764  0.697452  0.694987  0.867758
#
#    Execution Time (sec)
# 0            129.885195
